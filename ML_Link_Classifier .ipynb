# %%
# Manipulation libraries
import pandas as pd
import numpy as np

import nltk
import re

# %%
# Visualization libraries
import matplotlib.pyplot as plt
import heatmap
import seaborn as sns

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# ML libraries

from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb

from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# # Funcoes

# %% [markdown]
# Exploratory functions

# %%
def heat_map(df):
    corr = df.corr()
    ax = sns.heatmap(
        corr, 
        vmin=-1, vmax=1, center=0,
        cmap=sns.diverging_palette(20, 220, n=200),
        square=True
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        horizontalalignment='right'
    )

# %% [markdown]
# # Importing Data

# %% [markdown]
# Importing data from HTML rendered websites

# %%
df = pd.read_pickle(r'C:\Users\ponde\Documents\programacao\Python\FreshJobs\ 2020-11-14 18h59 dataset_pre_tolken.pkl')

# %%
df.head()
# Out:
#    Unnamed: 0         aTagContent                    href  \
# 0           0     Skip to Content                    Main
# 1           1   Shopify Careers                   careers
# 2           2     Life at Shopify         careers culture
# 3           3               Teams           careers teams
# 4           4       Work anywhere   careers work anywhere
#
#                                                 keys  \
# 0  class data ga event data ga action data trekki...
# 1  href class data ga event data ga action data t...
# 2                                href class itemprop
# 3                                href class itemprop
# 4                                href class itemprop
#
#                                           attributes  candidateMatch  \
# 0  in page link skip to main visuallyhidden focus...             0.0
# 1   marketing nav logo shopify Main Nav Logo Main...             0.0
# 2   marketing nav item marketing nav item primary...             0.0
# 3   marketing nav item marketing nav item primary...             0.0
# 4   marketing nav item marketing nav item primary...             0.0
#
#    len_aTagContent  len_aTagContent_group_between 60 and 175  \
# 0               15                                         0
# 1               19                                         0
# 2               15                                         0
# 3                5                                         0
# 4               13                                         0
#
#    len_aTagContent_group_under 60  len_href  num_keys  attr_job_yn
# 0                               1         5         7            0
# 1                               1         8         7            0
# 2                               1        16         3            0
# 3                               1        14         3            0
# 4                               1        22         3            0

# %%
y = df.cadidateMatch
X = df.drop('candidateMatch',axis='columns')

# %% [markdown]
# # Modeling

# %% [markdown]
# Logistic regression: Crossvalidation and gridsearch

# %%
lr = LogisticRegression()

# %%
lr_parameters = {
    'max_iter' : [100, 1000, 2000],
    "C" : [0.01 , 0.1, 1.0, 3.0, 5.0, 8.0]
}

# %%
lr_grid = GridSearchCV(lr, lr_parameters, cv=10, scoring='accuracy', return_train_score=False)

# %%
lr_grid.fit(X,y)
# Out:
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-4d2372ab8e5e> in <module>
# ----> 1 lr_grid.fit(X,y)
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1405         else:
#    1406             prefer = 'processes'
# -> 1407         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#    1408                                **_joblib_parallel_args(prefer=prefer))(
#    1409             path_func(X, y, pos_class=class_, Cs=[C_],
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     755             iprint = [-1, 50, 1, 100, 101][
#     756                 np.searchsorted(np.array([0, 1, 2, 3]), verbose)]
# --> 757             opt_res = optimize.minimize(
#     758                 func, w0, method="L-BFGS-B", jac=True,
#     759                 args=(X, target, 1. / C, sample_weight),
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\scipy\optimize\optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     114     grad = np.empty_like(w)
#     115
# --> 116     w, c, yz = _intercept_dot(w, X, y)
#     117
#     118     if sample_weight is None:
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py in _intercept_dot(w, X, y)
#      77         w = w[:-1]
#      78
# ---> 79     z = safe_sparse_dot(X, w) + c
#      80     yz = y * z
#      81     return w, c, yz
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
pd.DataFrame(lr_grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]

# %% [markdown]
# fim

# %% [markdown]
# Random Forest Classifier

# %%
rfc = RandomForestClassifier()

# %%
rfc_parameters = {
    'n_estimators': [10,50,100,150,300],
    'max_depth' : [2,3,4,5,8]
}

# %%
rfc_grid = GridSearchCV(rfc, rfc_parameters, cv=10, scoring='accuracy', return_train_score=False)

# %%
rfc_grid.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 3, 4, 5, 8],
#                          'n_estimators': [10, 50, 100, 150, 300]},
#              scoring='accuracy')

# %%
pd.DataFrame(rfc_grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score                                 params
# 0          0.787250        0.153072   {'max_depth': 2, 'n_estimators': 10}
# 1          0.756989        0.180727   {'max_depth': 2, 'n_estimators': 50}
# 2          0.785714        0.183622  {'max_depth': 2, 'n_estimators': 100}
# 3          0.778955        0.190433  {'max_depth': 2, 'n_estimators': 150}
# 4          0.773425        0.196060  {'max_depth': 2, 'n_estimators': 300}
# 5          0.801843        0.178267   {'max_depth': 3, 'n_estimators': 10}
# 6          0.800307        0.181988   {'max_depth': 3, 'n_estimators': 50}
# 7          0.803840        0.173026  {'max_depth': 3, 'n_estimators': 100}
# 8          0.806298        0.174631  {'max_depth': 3, 'n_estimators': 150}
# 9          0.792627        0.180674  {'max_depth': 3, 'n_estimators': 300}
# 10         0.844700        0.150866   {'max_depth': 4, 'n_estimators': 10}
# 11         0.826882        0.156705   {'max_depth': 4, 'n_estimators': 50}
# 12         0.815822        0.166493  {'max_depth': 4, 'n_estimators': 100}
# 13         0.813825        0.164883  {'max_depth': 4, 'n_estimators': 150}
# 14         0.832873        0.155042  {'max_depth': 4, 'n_estimators': 300}
# 15         0.845622        0.116177   {'max_depth': 5, 'n_estimators': 10}
# 16         0.850691        0.137210   {'max_depth': 5, 'n_estimators': 50}
# 17         0.863441        0.129921  {'max_depth': 5, 'n_estimators': 100}
# 18         0.837327        0.150792  {'max_depth': 5, 'n_estimators': 150}
# 19         0.846237        0.147046  {'max_depth': 5, 'n_estimators': 300}
# 20         0.843932        0.141803   {'max_depth': 8, 'n_estimators': 10}
# 21         0.862980        0.120285   {'max_depth': 8, 'n_estimators': 50}
# 22         0.881874        0.104300  {'max_depth': 8, 'n_estimators': 100}
# 23         0.864977        0.118009  {'max_depth': 8, 'n_estimators': 150}
# 24         0.873118        0.112639  {'max_depth': 8, 'n_estimators': 300}

# %% [markdown]
# fim

# %% [markdown]
# SCV

# %%
svc = SVC()

# %%
svc_parameters = [
    {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
    {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']}
]

# %%
svc_grid = GridSearchCV(svc, svc_parameters, cv=10, scoring='accuracy', return_train_score=False)

# %%
svc_grid.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-6893f329867e> in <module>
# ----> 1 svc_grid.fit(X,y)
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     215
#     216         seed = rnd.randint(np.iinfo('i').max)
# --> 217         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     218         # see comment on the other call to np.iinfo in this file
#     219
#
# c:\users\ponde\appdata\local\programs\python\python38\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     266         self.support_, self.support_vectors_, self._n_support, \
#     267             self.dual_coef_, self.intercept_, self._probA, \
# --> 268             self._probB, self.fit_status_ = libsvm.fit(
#     269                 X, y,
#     270                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %%
pd.DataFrame(svc_grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-864669906939> in <module>
# ----> 1 pd.DataFrame(svc_grid.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
#
# AttributeError: 'GridSearchCV' object has no attribute 'cv_results_'

# %% [markdown]
# Fim

# %% [markdown]
# # Deep diving the results

# %%
df['pred'] = model.predict(X)

# %%
erros = df[df['pred']!=df['candidateMatch']]
erros['company']
erros['candidateMatch']

# %%
df['erroType'] = np.where((df['candidateMatch']==1) & (df['pred']==0), 2,
                          np.where((df['candidateMatch']==0) & (df['pred']==1), 1,
                                  0
                                  )
                         )

# %%
pd.crosstab(df['company'],df['erroType'])

# %%
df[df['erroType']==1]
